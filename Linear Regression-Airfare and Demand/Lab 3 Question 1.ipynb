# %% [markdown]
# ###                                                                                         Name: Sharon Laurance Muthipeedika
# ###                                                                                         Matriculation No: 312486

# %% [markdown]
# ### Exercise 1: Gradient Descent on Rosenbrock function

# %%
# Importing Required Libraries
import matplotlib.pyplot as plt
from numpy import *
from numpy.linalg import norm
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.pyplot import *
from numpy import *

# %%
#To plot 3d Figure we use this 
fig = plt.figure()
ax = plt.axes(projection='3d')

# %% [markdown]
# #### 1. Implement a 3D plot to visualize the function (Use Matplotlib’s 3D utilities)

# %%
x=np.linspace(0, 15, 100)
y=np.linspace(0,15,100)
X, Y = meshgrid(x, y)
z=(1-X)**2+100*((Y-(X**2)))**2

# %%
fig=plt.rcParams['figure.figsize']=(6,6) 
X,Y=np.meshgrid(x,y)
z=(1-X)**2+100*((Y-(X**2)))**2
fig = figure(3)
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X,Y, z, rstride=1, cstride=1, cmap=cm.coolwarm,linewidth=0, antialiased=False)
# ax.set_zlim(0, 1500)
# ax.zaxis.set_major_locator(LinearLocator(10))
# ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
# fig.colorbar(surf, shrink=0.5, aspect=5)
show()

# %% [markdown]
# #### 2. Derive the partial gradients. (Please look into how to typeset latex in Jupyter notebooks

# %% [markdown]
# \begin{equation*}
# \begin{vmatrix}
# \mathbf{Column} \\
# \frac{\partial f}{\partial x} \\
# \frac{\partial f}{\partial y}
# \end{vmatrix}
# \end{equation*}

# %%
# x = symbols('x')
# y = symbols('y') 
#Define function
f = (1-x)**2+100*((y-(x**2)))**2
#Calculating Partial Derivative for x and y
derivative_fx = -400*x*(-x**2 + y) + 2*x - 2
derivative_fy = -200*x**2 + 200*y

# %% [markdown]
# #### 3. Convert the function and gradient of this function into equivalent code representation.

# %% [markdown]
# $\begin{equation*}
# \frac{\partial f}{\partial x} =-400*x*(y -x^2 ) + 2*x - 2\\
# \frac{\partial f}{\partial x} =-200*x^2 + 200*y
# \end{equation*}$

# %% [markdown]
# #### 4. Optimize the function with Gradient Descent. Set the appropriate hyperparameters like initial values of (x,y) and the steplength α through trial and error.

# %%
#Gradient Descent
def objective_function(x,y):
    f = (1-x)**2+100*((y-(x**2)))**2
    return f
def get_gradient(a,b):
    dx=-400*a*(-a**2 + b) + 2*a - 2
    dy=-200*a**2 + 200*b
    
    return dx,dy
def gradient_descent_algo(f,x,y,K,alpha):
    for k in range(0,K):
        gradient_direction=np.array(get_gradient(x,y))
        (x_old,y_old)=(x,y)
        print(x_old,y_old)
        (x,y)=(x_old,y_old)-np.dot(alpha,gradient_direction)
        print(x,y)
        print(objective_function(x_old,y_old)-objective_function(x,y))
#         if (np.linalg.norm(gradient_direction)<0.06): 
#             return (x,y)
        if(objective_function(x_old,y_old)-objective_function(x,y)<0.006):
            return (x,y)
        elif(k==1000):
            return "Did not converge in ",K," iterations"

# %%
f = (1-x)**2+100*((y-(x**2)))**2
x=10
y=10
alpha=0.00001
K=1000
result=gradient_descent_algo(f,x,y,K,alpha)
print("Result is",result)
print("Function value",objective_function(result[0],result[1]))
# Out:
# 10 10
# 6.39982 10.18
# 715325.1846376865
# 6.39982 10.18
# 5.611825145111704 10.2415553920648
# 49573.93554007942
# 5.611825145111704 10.2415553920648
# 5.134704738834483 10.284057444199286
# 19304.492750498666
# 5.134704738834483 10.284057444199286
# 4.804334517994687 10.316219714820907
# 9567.343725191507
# 4.804334517994687 10.316219714820907
# 4.558941223136469 10.341750535712855
# 5393.434602166619
# 4.558941223136469 10.341750535712855
# 4.368448639712866 10.362634924793456
# 3300.1864617090323
# 4.368448639712866 10.362634924793456
# 4.215997400378104 10.380076341979487
# 2138.1312293045803
# 4.215997400378104 10.380076341979487
# 4.091231335628421 10.394865457455518
# 1444.9792165220933
# 4.091231335628421 10.394865457455518
# 3.9873617428701857 10.407552074223863
# 1008.7285306598169
# 3.9873617428701857 10.407552074223863
# 3.899715582163543 10.418535077412425
# 722.4867094610163
# 3.899715582163543 10.418535077412425
# 3.8249507903484967 10.42811357050114
# 528.3224123470648
# 3.8249507903484967 10.42811357050114
# 3.7606024533103586 10.436517840457313
# 392.9965090975845
# 3.7606024533103586 10.436517840457313
# 3.704805892336432 10.443929066400086
# 296.5340180160965
# 3.704805892336432 10.443929066400086
# 3.656120178069837 10.450492381667068
# 226.46174168068865
# 3.656120178069837 10.450492381667068
# 3.613411505552613 10.456325826416712
# 174.7351998403542
# 3.613411505552613 10.456325826416712
# 3.5757737321992678 10.4615266601808
# 136.0211192894194
# 3.5757737321992678 10.4615266601808
# 3.5424727970878283 10.46617592242821
# 106.69852577625403
# 3.5424727970878283 10.46617592242821
# 3.5129069485489883 10.470341797619568
# 84.25750293580899
# 3.5129069485489883 10.470341797619568
# 3.486577709439364 10.474082144482656
# 66.92633512055647
# 3.486577709439364 10.474082144482656
# 3.4630683029661515 10.47744642844161
# 53.43413180063149
# 3.4630683029661515 10.47744642844161
# 3.4420273671351813 10.480477219726744
# 42.85614936675955
# 3.4420273671351813 10.480477219726744
# 3.423156485907703 10.483211370079506
# 34.51088727806396
# 3.423156485907703 10.483211370079506
# 3.4062005194713825 10.485680947993371
# 27.890341997658822
# 3.4062005194713825 10.485680947993371
# 3.390940017399814 10.487913990055079
# 22.611933890502172
# 3.390940017399814 10.487913990055079
# 3.3771852023541404 10.489935110478175
# 18.384864178557237
# 3.3771852023541404 10.489935110478175
# 3.364771152384694 10.491766000039219
# 14.98624213572532
# 3.364771152384694 10.491766000039219
# 3.3535539081614196 10.49342583785498
# 12.243929579784854
# 3.249261030830389 10.509007473797503
# 3.248583222485955 10.509104853342853
# 0.04485925386731715
# 3.248583222485955 10.509104853342853
# 3.2479640559393648 10.509193229543001
# 0.03742410021318143
# 3.2479640559393648 10.509193229543001
# 3.2473984184099356 10.509273384101263
# 0.031224789084438598
# 3.2473984184099356 10.509273384101263
# 3.246881648082369 10.509346030308842
# 0.026055100596137137
# 3.246881648082369 10.509346030308842
# 3.2464094934722594 10.509411819121533
# 0.021743416571889718
# 3.2464094934722594 10.509411819121533
# 3.2459780765938073 10.509471344681904
# 0.018146869449523706
# 3.2459780765938073 10.509471344681904
# 3.2455838595511084 10.509525149339995
# 0.015146491332802547
# 3.2455838595511084 10.509525149339995
# 3.245223614215729 10.509573728220072
# 0.012643189689336864
# 3.245223614215729 10.509573728220072
# 3.2448943946895312 10.50961753337616
# 0.01055440689307563
# 3.2448943946895312 10.50961753337616
# 3.2445935122836094 10.509656977574782
# 0.008811345934158332
# 3.2445935122836094 10.509656977574782
# 3.2443185127723386 10.509692437739538
# 0.0073566652169230196
# 3.2443185127723386 10.509692437739538
# 3.2440671557063867 10.509724258088694
# 0.00614256227707255
# 3.2440671557063867 10.509724258088694
# 3.24383739559057 10.509752752993982
# 0.005129180151780766
# Result is (3.24383739559057, 10.509752752993982)
# Function value 5.051007209853337

# %%
f = (1-x)**2+100*((y-(x**2)))**2
x=10
y=10
alpha=0.05
K=1000
result_new=gradient_descent_algo(f,x,y,K,alpha)
print("Result is",result_new)
print("Function value",objective_function(result_new[0],result_new[1]))
# Out:
# 10 10
# -17990.9 910.0
# -1.0476328704852814e+19
# Result is (-17990.9, 910.0)
# Function value 1.0476328704853625e+19

# %% [markdown]
# Faster convergence when step size is increased

# %% [markdown]
# #### 5. Visualize the trajectory on the same 3D plot. This trajectory should ideally lead to the function minimum, starting off with (x = 10, y = 10) for example.

# %%
x=np.linspace(-5, 5, 200)
y=np.linspace(-5,5,200)
X, Y = np.meshgrid(x, y)
z=(1-X)**2+100*((Y-(Y**2)))**2
# fig = figure(3)
# fig = plt.figure()
ax = plt.axes(projection='3d')
# ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, z, rstride=5, cstride=5, cmap='jet',alpha=.5,linewidth=2,edgecolor="none")
ax.plot(result[0],result[1],objective_function(result[0],result[1]),color='black',marker='*',alpha=.5)
ax.set_zlim(0,48000)
ax.view_init(45,280)

# ax.zaxis.set_major_locator(LinearLocator(10))
# ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# #### References
#  - https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html
#  - https://medium.com/analytics-vidhya/writing-math-equations-in-jupyter-notebook-a-naive-introduction-a5ce87b9a214
